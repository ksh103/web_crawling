# %%
import json

data = """ {
"lastBuildDate": "Thu, 06 May 2021 15:02:24 +0900",
"total": 7411352,
"start": 1,
"display": 10,
"items": [
{
"title": "日 긴급사태 연장 여부 내일 결정…스가 “사람 이동 감소” 발언 논란",
"originallink": "https://news.kbs.co.kr/news/view.do?ncd=5179647&amp;ref=A",
"link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=104&oid=056&aid=0011039300",
"description": "일본 정부가 도쿄도 등 4개 광역지역에 발령한 <b>코로나</b>19 긴급사태를 연장하는 방향을 검토하고 있다고 NHK방송 등이 6일 보도했습니다. 일본 정부는 7일 <b>코로나</b>19 대책본부 회의를 열고 다음 주 11일까지인 긴급사태 발령의... ",
"pubDate": "Thu, 06 May 2021 15:01:00 +0900"

},
{
"title": "<b>코로나</b> 이후 외식창업 키워드는? ‘소자본, 배달, 공유주방’",
"originallink": "http://news.kmib.co.kr/article/view.asp?arcid=0015817918&code=61141111&cp=nv",
"link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=005&aid=0001436955",
"description": "그러나 안정적인 외식창업을 목표로 한다면 <b>코로나</b> 이후 외식시장의 회복까지 고려해야 한다. 백신 접종이 시작되면서 배달시장은 언제든 변할 수 있어 배달뿐 아니라 홀 운영도 병행할 수 있는 공유주방을 선택하는 것이... ",
"pubDate": "Thu, 06 May 2021 15:01:00 +0900"

},
{
"title": "산단공, 오는 14일 '영남권 산업단지 투자설명회' 개최",
"originallink": "http://www.edaily.co.kr/news/newspath.asp?newsid=02765046629046296",
"link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=018&aid=0004922026",
"description": "산단공 관계자는 “<b>코로나</b>19에 따른 경기 악화로 투자가 위축된 상황에서 민간의 아이디어와 전문역량을 활용해 지역 산업단지의 활력을 모색하고자 한다”며 “수도권에서 눈을 돌려 영남권에서 새로운 투자 기회를... ",
"pubDate": "Thu, 06 May 2021 15:01:00 +0900"

},
{
"title": "전남교육청, EBS 연계 수능 대비 '온라인 특강' 실시",
"originallink": "https://www.nocutnews.co.kr/news/5548343",
"link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=079&aid=0003501084",
"description": "<b>코로나</b>19 예방을 위해 온라인 쌍방향 강의로 진행되는 이번 프로그램에서는 실시간 질의응답을 통해 참가자들의 만족도를 높일 예정이다. 전라남도교육청 관계자는 &quot;<b>코로나</b>19로 인해 학습량이 부족한 고등학교 3학년... ",
"pubDate": "Thu, 06 May 2021 15:01:00 +0900"
}
]
}
"""

json_data = json.loads(data)
print(json_data['items'][0]['title'])
# print(json_data['items'][0]['link'])
print(json_data['items'][0]['description'])
# Out:
# 日 긴급사태 연장 여부 내일 결정…스가 “사람 이동 감소” 발언 논란
# 일본 정부가 도쿄도 등 4개 광역지역에 발령한 <b>코로나</b>19 긴급사태를 연장하는 방향을 검토하고 있다고 NHK방송 등이 6일 보도했습니다. 일본 정부는 7일 <b>코로나</b>19 대책본부 회의를 열고 다음 주 11일까지인 긴급사태 발령의...

# %% [markdown]
# ### 네이버 OPEN API로 크롤링하기

# %%
import requests
import pprint

client_id = 'V7lY6SlQs6CAuPrmKeXY'
client_secret = 'JcSdEMQTaJ'

naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query=애플&display=10'
header_params = {"X-naver-client-id": client_id, "X-naver-client-secret":client_secret}
res = requests.get(naver_open_api, headers=header_params)

if res.status_code == 200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print(index + 1, item['title'])
else:
    print("Error code : ", res.status_code)
# Out:
# 1 엔픽셀, '그랑사가' 서비스 100일 기념 이벤트
# 2 엔픽셀, '그랑사가' 서비스 100일 기념 대규모 이벤트 진행
# 3 엇갈리는 다우와 나스닥...시장은 이미 인플레 반영하나
# 4 TSMC, 美 반도체 증설 강공…추격자 삼성전자의 부담
# 5 소녀시대 태연, 보라색 아이폰 출시에 &quot;나도 알아, 안다고ㅠㅠ&quot;
# 6 “아이폰 새로운 색깔 나오자 좌절한 태연… 결국 뜻밖의 사진 올렸다”
# 7 전자랜드, 온오프라인 동시 '가정의달' 경품 이벤트 진행
# 8 &quot;로컬‧소상공인 브랜드 육성, 고용창출로 미래 희망 열어&quot;
# 9 HJN, 하자 보수·수리 O2O 서비스 앱 '하자노' 출시
# 10 <b>애플</b>, 하반기 실적상승 포인트는?

# %%
import requests
import openpyxl

client_id = 'V7lY6SlQs6CAuPrmKeXY'
client_secret = 'JcSdEMQTaJ'
start, num = 1,0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions['B'].width = 100
excel_sheet.column_dimensions['C'].width = 100
excel_sheet.append(['랭킹','제목','링크'])

for index in range(10):
    start_number = start + (index * 100)
    naver_open_api = "https://openapi.naver.com/v1/search/shop.json?query=샤오미&display=10&start=" +str(start_number)
    header_params = {"X-naver-client-id": client_id, "X-naver-client-secret":client_secret}
    res = requests.get(naver_open_api, headers = header_params)
    if res.status_code == 200:
        data = res.json()
        for item in data['items']:
            num += 1
            excel_sheet.append([num, item['title'], item['link']])
    else:
        print("Error Code : ", res.status_code)
excel_file.save('IT.xlsx')
excel_file.close()

# %% [markdown]
# ### 정부제공 공공 데이터 Open API 사용

# %%
import requests

service_key = "Uq94XHLzIOs2%2FSeD%2FUlvP3AoHjxp7DHz55ysWj99GOyiw%2F8EMbPRGjqHS%2FMqU1Ic3RIBjA%2Fy1CG6Ttj5yuPWtg%3D%3D"
params = "&NumofRows=10&PageNo=1&sidoName=부산"
open_api = "http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?serviceKey=" + service_key + params

res = requests.get(open_api)

print(res.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <response>
#   <header>
#     <resultCode>00</resultCode>
#     <resultMsg>NORMAL_CODE</resultMsg>
#   </header>
#   <body>
#     <items>
#       <item>
#         <so2Grade>1</so2Grade>
#         <coFlag/>
#         <khaiValue>77</khaiValue>
#         <so2Value>0.002</so2Value>
#         <coValue>0.2</coValue>
#         <pm10Flag/>
#         <o3Grade>2</o3Grade>
#         <pm10Value>67</pm10Value>
#         <khaiGrade>2</khaiGrade>
#         <sidoName>부산</sidoName>
#         <no2Flag/>
#         <no2Grade>1</no2Grade>
#         <o3Flag/>
#         <so2Flag/>
#         <dataTime>2021-05-06 16:00</dataTime>
#         <coGrade>1</coGrade>
#         <no2Value>0.018</no2Value>
#         <stationName>광복동</stationName>
#         <pm10Grade>2</pm10Grade>
#         <o3Value>0.043</o3Value>
#       </item>
#       <item>
#         <so2Grade/>
#         <coFlag>점검및교정</coFlag>
#         <khaiValue>-</khaiValue>
#         <so2Value>-</so2Value>
# ...

# %%
import requests
from bs4 import BeautifulSoup

service_key = "Uq94XHLzIOs2%2FSeD%2FUlvP3AoHjxp7DHz55ysWj99GOyiw%2F8EMbPRGjqHS%2FMqU1Ic3RIBjA%2Fy1CG6Ttj5yuPWtg%3D%3D"
params = "&NumofRows=10&PageNo=1&sidoName=부산"
open_api = "http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?serviceKey=" + service_key + params
res = requests.get(open_api)
soup = BeautifulSoup(res.content, 'html.parser')

data = soup.find_all('item')
for item in data:
    stationname = item.find('stationname')
    pm10grade = item.find('pm10grade')
    print(stationname.get_text(),pm10grade.get_text())
# Out:
# 광복동 2
# 초량동 2
# 태종대 2
# 청학동 2
# 전포동 2
# 온천동 2
# 명장동 2
# 대연동 2
# 학장동 2
# 덕천동 2

# %%
import requests
open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty'
serviceKey = '?serviceKey=Uq94XHLzIOs2%2FSeD%2FUlvP3AoHjxp7DHz55ysWj99GOyiw%2F8EMbPRGjqHS%2FMqU1Ic3RIBjA%2Fy1CG6Ttj5yuPWtg%3D%3D'
returnType = '&returnType=json'
numOfRows = '&numOfRows=100'
sidoName = '&sidoName=서울'
res = requests.get(open_api + serviceKey + returnType + numOfRows + sidoName)
#print(res.text)
if res.status_code == 200:
    data = res.json()
    print(data['response']['body']['items'])
    # for index, item in enumerate(data['items']):
    #     print (index, item)
else:
    print("Error Code:", res.status_code)
# Out:
# [{'so2Grade': '1', 'coFlag': None, 'khaiValue': '94', 'so2Value': '0.004', 'coValue': '0.5', 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '97', 'khaiGrade': '2', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2021-05-06 16:00', 'coGrade': '1', 'no2Value': '0.021', 'stationName': '중구', 'pm10Grade': '2', 'o3Value': '0.073'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '99', 'so2Value': '0.003', 'coValue': '0.8', 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '110', 'khaiGrade': '2', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '2', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2021-05-06 16:00', 'coGrade': '1', 'no2Value': '0.033', 'stationName': '한강대로', 'pm10Grade': '2', 'o3Value': '0.036'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '95', 'so2Value': '0.005', 'coValue': '0.5', 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '96', 'khaiGrade': '2', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'so2Flag'
# ...
